# %% [markdown]
# # K-mean clustering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_set= pd.read_csv("/Users/satyarth/Downloads/Clusterting_assignment.csv")
data_set
# Out:
#                 x           y
# 0      297.216570  215.201762
# 1      303.853140  197.927574
# 2      309.279379  222.031763
# 3      262.516493  223.440465
# 4      275.783383  199.122742
# ...           ...         ...
# 2471   963.225592  205.402847
# 2472   963.548633  210.032341
# 2473  1009.767785  162.638040
# 2474   977.240645  144.597832
# 2475   972.909736  144.251109
#
# [2476 rows x 2 columns]

# %%
data_set_p=data_set.values

# %%
from sklearn.cluster import KMeans

# %%
wcss=[]
#WCSS is defined as the sum of the squared distance between each member of the cluster and its centroid.

for i in range(1,11):
    kmeans = KMeans(n_clusters=i,init='k-means++',random_state=42)
    kmeans.fit(data_set_p)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1,11),wcss)# here optimum point is between 6 and 8

# %%
kmeans = KMeans(n_clusters=2,init='k-means++',random_state=42)
y_kmeans=kmeans.fit_predict(data_set_p)
y_kmeans
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int32)

# %%
my_clusters=pd.DataFrame({'clusters':range(1,11),'WSS':wcss})*.00001
my_clusters
# Out:
#    clusters          WSS
# 0   0.00001  3114.388656
# 1   0.00002  1423.844937
# 2   0.00003   605.477573
# 3   0.00004   465.706214
# 4   0.00005   340.697919
# 5   0.00006   242.094301
# 6   0.00007   158.396968
# 7   0.00008   137.553603
# 8   0.00009   116.916702
# 9   0.00010    99.303734

# %%
plt.scatter(data_set_p[y_kmeans==0,0],data_set_p[y_kmeans==0,1], s=100,c='red',label='cluster 1')
#here we are taking L as dependent variable and for y_kmeans we set zero first because it has value 0 in above result
#and zero in second place represents the index of x (first column of x) and 1 in second place in second term represents
#the second column of x
plt.scatter(data_set_p[y_kmeans==1,0],data_set_p[y_kmeans==1,1] ,s=100,c='blue',label='cluster 2')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=100,c='orange')

# %%
kmeans = KMeans(n_clusters=4,init='k-means++',random_state=42)
y_kmeans=kmeans.fit_predict(data_set_p)
y_kmeans
# Out:
# array([2, 2, 2, ..., 1, 1, 1], dtype=int32)

# %%
plt.scatter(data_set_p[y_kmeans==1,0],data_set_p[y_kmeans==1,1] ,s=100,c='blue',label='cluster 2')
plt.scatter(data_set_p[y_kmeans==2,0],data_set_p[y_kmeans==2,1] ,s=100,c='green',label='cluster 3')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=100,c='orange')

# %%
kmeans = KMeans(n_clusters=5,init='k-means++',random_state=42)
y_kmeans=kmeans.fit_predict(data_set_p)
y_kmeans
# Out:
# array([3, 3, 3, ..., 0, 0, 0], dtype=int32)

# %%
plt.scatter(data_set_p[y_kmeans==0,0],data_set_p[y_kmeans==0,1], s=100,c='red',label='cluster 1')
#here we are taking L as dependent variable and for y_kmeans we set zero first because it has value 0 in above result
#and zero in second place represents the index of x (first column of x) and 1 in second place in second term represents
#the second column of x
plt.scatter(data_set_p[y_kmeans==1,0],data_set_p[y_kmeans==1,1] ,s=100,c='blue',label='cluster 2')
plt.scatter(data_set_p[y_kmeans==2,0],data_set_p[y_kmeans==2,1] ,s=100,c='green',label='cluster 3')
plt.scatter(data_set_p[y_kmeans==3,0], data_set_p[y_kmeans==3,1],s=100,c='pink',label='cluster 4')
#plt.scatter(data_set_p[y_kmeans==4,0],data_set_p[y_kmeans==4,1] ,s=100,c='yellow',label='cluster 5')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=100,c='orange')

# %%
kmeans = KMeans(n_clusters=8,init='k-means++',random_state=42)
y_kmeans=kmeans.fit_predict(data_set_p)
y_kmeans
# Out:
# array([4, 4, 4, ..., 3, 3, 3], dtype=int32)

# %%
plt.scatter(data_set_p[y_kmeans==0,0],data_set_p[y_kmeans==0,1], s=100,c='red',label='cluster 1')
#here we are taking L as dependent variable and for y_kmeans we set zero first because it has value 0 in above result
#and zero in second place represents the index of x (first column of x) and 1 in second place in second term represents
#the second column of x
plt.scatter(data_set_p[y_kmeans==1,0],data_set_p[y_kmeans==1,1] ,s=100,c='blue',label='cluster 2')
plt.scatter(data_set_p[y_kmeans==2,0],data_set_p[y_kmeans==2,1] ,s=100,c='green',label='cluster 3')
plt.scatter(data_set_p[y_kmeans==3,0], data_set_p[y_kmeans==3,1],s=100,c='pink',label='cluster 4')
plt.scatter(data_set_p[y_kmeans==4,0],data_set_p[y_kmeans==4,1] ,s=100,c='yellow',label='cluster 5')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=100,c='orange')

# %%
kmeans = KMeans(n_clusters=10,init='k-means++',random_state=42)
y_kmeans=kmeans.fit_predict(data_set_p)
y_kmeans
# Out:
# array([2, 2, 2, ..., 4, 4, 4], dtype=int32)

# %%
plt.scatter(data_set_p[y_kmeans==0,0],data_set_p[y_kmeans==0,1], s=100,c='red',label='cluster 1')
#here we are taking L as dependent variable and for y_kmeans we set zero first because it has value 0 in above result
#and zero in second place represents the index of x (first column of x) and 1 in second place in second term represents
#the second column of x
plt.scatter(data_set_p[y_kmeans==1,0],data_set_p[y_kmeans==1,1] ,s=100,c='blue',label='cluster 2')
plt.scatter(data_set_p[y_kmeans==2,0],data_set_p[y_kmeans==2,1] ,s=100,c='green',label='cluster 3')
plt.scatter(data_set_p[y_kmeans==3,0], data_set_p[y_kmeans==3,1],s=100,c='pink',label='cluster 4')
plt.scatter(data_set_p[y_kmeans==4,0],data_set_p[y_kmeans==4,1] ,s=100,c='yellow',label='cluster 5')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=100,c='orange')

# %%
import sklearn.metrics as metrics
import sklearn.cluster as cluster

# %%
for i in range(2,11):
    labels=cluster.KMeans(n_clusters=i,init='k-means++',random_state=200).fit(data_set_p).labels_
    print("S-score for k clusters"+str(i)+"is"+str(metrics.silhouette_score(data_set_p,labels,metric='euclidean',sample_size=2476,random_state=200)))
# Out:
# S-score for k clusters2is0.5082869500879653
# S-score for k clusters3is0.6141757354070043
# S-score for k clusters4is0.6043106688320848
# S-score for k clusters5is0.6041118693518223
# S-score for k clusters6is0.6493438935658798
# S-score for k clusters7is0.6211449984359377
# S-score for k clusters8is0.5949297984448728
# S-score for k clusters9is0.5875746926593888
# S-score for k clusters10is0.5834541585673177

# %% [markdown]
# # DBSCAN clustering

# %%
from sklearn.datasets import make_blobs
data_set,_=make_blobs(n_samples=500, centers=3,n_features=2,random_state=20)
# here n_samples indicates how many data points we want to produce.
# centers , indicates how many clusters will be there
# n_features shows the dimensionality of our data set

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan=DBSCAN(eps=1,min_samples=5).fit(data_set)
cluster_d=dbscan.labels_

# %%
len(set(cluster_d))
# Out:
# 4

# %%
from pandas import DataFrame
df=DataFrame(dict(x=data_set[:,0],y=data_set[:,1]))

# %%
def show_clusters(data_set,cluster_d):
    df=DataFrame(dict(x=data_set[:,0],y=data_set[:,1],label=cluster))
    colors={-1:'blue',0:'green',1:'orange',2:'pink',3:'red'}
    fig, ax=plt.subplots(figsize=(8,8))
    grouped=df.groupby('label')
    for key,group in grouped:
        group.plot(ax=ax,kind='scatter',x='x',y='y',label=key,color=colors[key])
    plt.xlabel('x-1')
    plt.ylabel('y-1')
    plt.show()
    #here dots in blue show the noise

# %%
show_clusters(data_set,cluster_d)

# %% [markdown]
# # Spectral clustering

# %%
from sklearn.cluster import SpectralClustering
import matplotlib.pyplot as plt

# Create synthetic data
data_set, labels = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=42)
# here make blobs is used to make clusters

# Apply spectral clustering
spectral_clustering = SpectralClustering(n_clusters=4, affinity='nearest_neighbors', random_state=42)
predicted_labels = spectral_clustering.fit_predict(data_set)

# Plot the results
plt.scatter(data_set[:, 0], data_set[:, 1], c=predicted_labels, s=50, cmap='viridis')
plt.show()
# Out:
# /Users/satyarth/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_spectral_embedding.py:260: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(

# %%
n_clusters = 2
clustering = SpectralClustering(n_clusters=n_clusters, affinity='nearest_neighbors', random_state=42)
labels_spectral = clustering.fit_predict(data_set)
# Out:
# /Users/satyarth/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_spectral_embedding.py:260: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(

# %%
from sklearn.metrics import silhouette_score
silhouette_avg = silhouette_score(data_set, labels_spectral)
print(f"Average silhouette score: {silhouette_avg:.2f}")
# Out:
# Average silhouette score: 0.32

# %%
n_clusters_n1 = 4
clustering_n1 = SpectralClustering(n_clusters=n_clusters_n1, affinity='nearest_neighbors', random_state=42)
labels_spectral = clustering_n1.fit_predict(data_set)
# Out:
# /Users/satyarth/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_spectral_embedding.py:260: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(

# %%
from sklearn.metrics import silhouette_score
silhouette_avg = silhouette_score(data_set, labels_spectral)
print(f"Average silhouette score: {silhouette_avg:.2f}")
# Out:
# Average silhouette score: 0.51

# %%
n_clusters_n2 = 5
clustering_n2 = SpectralClustering(n_clusters=n_clusters_n2, affinity='nearest_neighbors', random_state=42)
labels_spectral = clustering_n2.fit_predict(data_set)
# Out:
# /Users/satyarth/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_spectral_embedding.py:260: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(

# %%
from sklearn.metrics import silhouette_score
silhouette_avg = silhouette_score(data_set, labels_spectral)
print(f"Average silhouette score: {silhouette_avg:.2f}")
# Out:
# Average silhouette score: 0.32

# %%
n_clusters_n3 = 8

clustering_n3 = SpectralClustering(n_clusters=n_clusters_n3, affinity='nearest_neighbors', random_state=42)
labels_spectral = clustering_n3.fit_predict(data_set)
# Out:
# /Users/satyarth/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_spectral_embedding.py:260: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(

# %%
from sklearn.metrics import silhouette_score
silhouette_avg = silhouette_score(data_set, labels_spectral)
print(f"Average silhouette score: {silhouette_avg:.2f}")
# Out:
# Average silhouette score: 0.13

# %%
n_clusters_n4= 10

clustering_n4 = SpectralClustering(n_clusters=n_clusters_n4, affinity='nearest_neighbors', random_state=42)
labels_spectral = clustering_n4.fit_predict(data_set)
# Out:
# /Users/satyarth/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_spectral_embedding.py:260: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(

# %%
from sklearn.metrics import silhouette_score
silhouette_avg = silhouette_score(data_set, labels_spectral)
print(f"Average silhouette score: {silhouette_avg:.2f}")
# Out:
# Average silhouette score: 0.35

# %% [markdown]
# # Agglomerative clustering

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
# Perform hierarchical clustering
Z = linkage(data_set, method='ward')

# %%
# Plot the dendrogram
plt.figure(figsize=(10, 5))
dendrogram(Z)
plt.xlabel('Data Points')
plt.ylabel('Distance')
plt.title('Hierarchical Clustering Dendrogram')
plt.show()

# %%
from scipy.cluster.hierarchy import fcluster

# Define the number of clusters
k = 3

# Cut the dendrogram to obtain clusters
clusters = fcluster(Z, k, criterion='maxclust')

print("Assigned clusters:", clusters)
# Out:
# Assigned clusters: [3 3 3 1 3 1 2 1 3 2 3 2 3 3 3 3 3 2 3 3 2 3 1 3 3 3 3 1 1 2 3 2 3 2 3 3 3
#  1 3 1 2 3 3 1 3 3 3 2 3 2 1 3 1 3 1 2 3 2 2 3 3 2 2 3 1 1 1 1 1 3 1 1 3 2
#  3 3 1 1 3 1 3 3 3 3 1 3 3 2 2 2 3 3 3 3 3 3 1 3 3 3 2 2 2 3 3 3 3 3 1 3 2
#  3 3 3 3 2 3 1 3 1 1 1 3 3 1 3 3 3 3 1 2 3 3 3 3 2 2 3 3 1 3 2 1 3 2 2 2 2
#  1 3 3 3 2 1 3 2 1 3 3 2 3 3 1 3 2 3 1 3 3 3 3 3 1 2 2 1 1 2 2 1 3 3 3 2 2
#  3 1 3 2 2 1 1 1 3 2 1 1 2 2 3 3 3 1 2 3 1 1 3 1 3 3 1 1 2 3 1 3 3 3 3 3 1
#  3 1 2 2 3 3 2 2 2 3 3 1 2 1 3 2 3 3 3 1 1 2 3 1 1 1 3 1 3 1 3 2 1 3 2 3 3
#  3 2 3 3 3 1 2 1 2 2 3 3 1 2 2 3 3 1 3 3 2 2 2 2 1 3 2 1 2 2 1 3 1 2 3 3 3
#  2 3 3 3]

# %%
# Plot the clusters
plt.scatter(data_set[:, 0], data_set[:, 1], c=clusters, cmap='rainbow')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Hierarchical Clustering Results')
plt.show()

# %%
Z = linkage(data_set, method='ward')

# Determine the number of clusters using the cophenetic distance
cophenetic_dist = np.max(data_set[:, 1])
max_d = cophenetic_dist * 0.7  # Adjust this threshold as needed
clusters = fcluster(Z, t=max_d, criterion='distance')

# %%
silhouette_avg = silhouette_score(data_set, clusters)
print(f"Average silhouette score for hierarchical clusters: {silhouette_avg:.2f}")
# Out:
# Average silhouette score for hierarchical clusters: 0.88

# %%
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage

data_set, labels = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)

# Perform agglomerative clustering
n_clusters = 4
clustering_agg = AgglomerativeClustering(n_clusters=n_clusters)
predicted_labels = clustering.fit_predict(data_set)
# Out:
# /Users/satyarth/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_spectral_embedding.py:260: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(

# %%
n_clusters = 4
clustering = AgglomerativeClustering(n_clusters=n_clusters)
predicted_labels = clustering.fit_predict(data_set)

# %%
plt.scatter(data_set[:, 0], data_set[:, 1], c=predicted_labels, cmap='viridis', s=50)
plt.title("Agglomerative Clustering Results")
plt.show()

# %%
n_clusters_a = 2
clustering_agg_1 = AgglomerativeClustering(n_clusters=n_clusters_a)
predicted_labels = clustering_agg_1.fit_predict(data_set)

# Calculate silhouette score
silhouette_avg = silhouette_score(data_set, predicted_labels)
print(f"Average silhouette score for agglomerative clustering: {silhouette_avg:.2f}")
# Out:
# Average silhouette score for agglomerative clustering: 0.55

# %%
n_clusters_a = 4
clustering_agg_2 = AgglomerativeClustering(n_clusters=n_clusters_a)
predicted_labels = clustering_agg_2.fit_predict(data_set)

# Calculate silhouette score
silhouette_avg = silhouette_score(data_set, predicted_labels)
print(f"Average silhouette score for agglomerative clustering: {silhouette_avg:.2f}")
# Out:
# Average silhouette score for agglomerative clustering: 0.68

# %%
n_clusters_a = 5
clustering_agg_3 = AgglomerativeClustering(n_clusters=n_clusters_a)
predicted_labels = clustering_agg_3.fit_predict(data_set)

# Calculate silhouette score
silhouette_avg = silhouette_score(data_set, predicted_labels)
print(f"Average silhouette score for agglomerative clustering: {silhouette_avg:.2f}")
# Out:
# Average silhouette score for agglomerative clustering: 0.59

# %%
n_clusters_a = 8
clustering_agg_4 = AgglomerativeClustering(n_clusters=n_clusters_a)
predicted_labels = clustering_agg_4.fit_predict(data_set)

# Calculate silhouette score
silhouette_avg = silhouette_score(data_set, predicted_labels)
print(f"Average silhouette score for agglomerative clustering: {silhouette_avg:.2f}")
# Out:
# Average silhouette score for agglomerative clustering: 0.29

# %%
n_clusters_a = 10
clustering_agg_5 = AgglomerativeClustering(n_clusters=n_clusters_a)
predicted_labels = clustering_agg_5.fit_predict(data_set)

# Calculate silhouette score
silhouette_avg = silhouette_score(data_set, predicted_labels)
print(f"Average silhouette score for agglomerative clustering: {silhouette_avg:.2f}")
# Out:
# Average silhouette score for agglomerative clustering: 0.32

# %%
#here agglomoretive clustering giving better sillhouette score.
